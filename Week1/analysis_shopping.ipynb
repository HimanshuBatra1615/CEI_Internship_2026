# %%
import pandas as pd

df = pd.read_csv("Combined_dataset.csv")
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
print("Head:")
print(df.head())


print("\nTail:")
print(df.tail())


print("\nShape:")
print(df.shape)


print("\nColumns:")
print(df.columns)


print("\nData Types:")
print(df.dtypes)


print("\nSummary:")
print(df.describe(include='all'))
# Out:
# Head:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
print(df.isnull().sum())
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']

# %%
selected_data = df[['product_id','title', 'category', 'final_price']]
selected_data.head()
# Out:
#    product_id           title   category  final_price
# 0     8376765     Lino Perros  backpacks  "₹3,995.00"
# 1     9136281  Tommy Hilfiger  backpacks  "₹2,899.00"
# 2    17633752           Lavie  backpacks  "₹2,999.00"
# 3     1376949          F Gear  backpacks  "₹1,675.00"
# 4    13939916       MYTRIDENT  bath-robe  "₹2,899.00"

# %%
print(df['final_price'].dtype)
print(df['final_price'].head())
# Out:
# object
# 0    "₹3,995.00"
# 1    "₹2,899.00"
# 2    "₹2,999.00"
# 3    "₹1,675.00"
# 4    "₹2,899.00"
# Name: final_price, dtype: object

# %%
df['final_price'] = (
    df['final_price']
    .astype(str)
    .str.replace('"', '', regex=False)
    .str.replace('₹', '', regex=False)
    .str.replace(',', '', regex=False)
)

df['final_price'] = pd.to_numeric(df['final_price'], errors='coerce')

print(df['final_price'].head())
print(df['final_price'].dtype)
# Out:
# 0    3995.0
# 1    2899.0
# 2    2999.0
# 3    1675.0
# 4    2899.0
# Name: final_price, dtype: float64
# float64

# %%
filtered_data = df[df['final_price'] > 1000]

filtered_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0       3995.0      INR
# 1     4.5             67           2899      35.0       2899.0      INR
# 2     4.4            226           2999      65.0       2999.0      INR
# 3     4.4           1052           1675      52.0       1675.0      INR
# 4     4.7             12           2899      17.0       2899.0      INR
#
#                                               images  ...  \
# ...

# %%
print("Before:", df.shape)

df.drop_duplicates(inplace=True)

print("After:", df.shape)
# Out:
# Before: (1000, 24)
# After: (1000, 24)

# %%
df['quantity'] = 1

df['total_amount'] = df['final_price'] * df['quantity']

df[['title', 'final_price', 'quantity', 'total_amount']].head()
# Out:
#             title  final_price  quantity  total_amount
# 0     Lino Perros       3995.0         1        3995.0
# 1  Tommy Hilfiger       2899.0         1        2899.0
# 2           Lavie       2999.0         1        2999.0
# 3          F Gear       1675.0         1        1675.0
# 4       MYTRIDENT       2899.0         1        2899.0

# %%
df.to_csv("cleaned_shopping_dataset.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %% [markdown]
# # Summary
#
# This project demonstrates basic data exploration and cleaning using Pandas.
#
# Tasks performed:
# - Loaded Combined_dataset.csv into a Pandas DataFrame.
# - Explored the dataset using head(), tail(), shape, columns, and data types.
# - Identified and handled missing values.
# - Selected relevant columns and filtered records.
# - Removed duplicate entries.
# - Created a derived column named total_amount.
# - Saved the cleaned dataset as cleaned_dataset.csv.
#
# Tools Used:
# - Python
# - Pandas
